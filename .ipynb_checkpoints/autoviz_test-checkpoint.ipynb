# %%
import pandas as pd
from autoviz.AutoViz_Class import AutoViz_Class

df = pd.read_csv('datasets/Social_Network_Ads.csv')
sep = " "
target = 'Gender'

# %%
Av = AutoViz_Class()

# %%
dft = Av.AutoViz(
    '',
    sep,
    target,
    df,
    header=0,
    verbose=0,
    lowess=False,
    chart_format="svg",
    max_rows_analyzed=150000,
    max_cols_analyzed=30,
)
# Out:
# Shape of your Data Set: (400, 5)
# Classifying variables in data set...
#     4 Predictors classified...
#         This does not include the Target column(s)
#     1 variables removed since they were ID or low-information variables
# Nothing to add Plot not being added
# Nothing to add Plot not being added
# Could not draw Pivot Charts against Dependent Variable
# Nothing to add Plot not being added
# All plots done
# Time to run AutoViz (in seconds) = 1.155

# %%
type(Av.AutoViz(
    '',
    sep,
    target,
    df,
    header=0,
    verbose=2,
    lowess=False,
    chart_format="svg",
    max_rows_analyzed=150000,
    max_cols_analyzed=30,
))
# Out:
# Shape of your Data Set: (400, 5)
# Classifying variables in data set...
#     4 Predictors classified...
#         This does not include the Target column(s)
#     1 variables removed since they were ID or low-information variables
#     List of variables removed: ['User ID']
# Nothing to add Plot not being added
# Nothing to add Plot not being added
# Could not draw Pivot Charts against Dependent Variable
# Nothing to add Plot not being added
# All plots done
# Time to run AutoViz (in seconds) = 1.879
# pandas.core.frame.DataFrame

# %%
Av.heat_map
# Out:
# {'name': 'heatmap',
#  'heading': 'Heatmap of all Continuous Variables for target Variable',
#  'plots': [],
#  'subheading': [],
#  'desc': []}

# %%
contents = Av.scatter_plot['plots'][1][0]

# %%
type(contents)
# Out:
# list

# %%
f = open('plot.svg', 'w+b')
f.write(contents)
f.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-3df27b20f8aa> in <module>
#       1 f = open('plot2.svg', 'w')
# ----> 2 f.write(contents)
#       3 f.close()
#
# TypeError: write() argument must be str, not list
