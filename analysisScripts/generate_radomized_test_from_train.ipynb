# %%
import pandas as pd

# %%
datasetName = 'used Cars Price_reg'
target = 'Price'

# %%
#df = pd.read_csv(f'./{datasetName}.csv').dropna()
df = pd.read_csv(f'./{datasetName}.csv').drop(['Unnamed: 0', 'New_Price'], axis = 1).dropna()
print(df.shape)
df.head()
# Out:
# (5975, 12)
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    Price
# 0   1.75
# 1  12.50
# 2   4.50
# 3   6.00
# ...

# %%
df2 = df.sample(frac=1).reset_index(drop=True).iloc[:100, df.columns != target]
df2
# Out:
#                                          Name    Location  Year  \
# 0   Mercedes-Benz E-Class E250 CDI Avantgrade      Mumbai  2014
# 1                         Honda City i VTEC V       Kochi  2015
# 2                    Maruti Wagon R LXI Minor      Jaipur  2006
# 3            Skoda Superb Elegance 1.8 TSI AT       Delhi  2014
# 4   Tata Nexon 1.5 Revotorq XZ Plus Dual Tone      Mumbai  2018
# ..                                        ...         ...   ...
# 95        Hyundai i20 2015-2017 1.4 Magna ABS        Pune  2012
# 96                      Maruti Omni 5 Str STD  Coimbatore  2010
# 97               Maruti Baleno Zeta Automatic       Kochi  2017
# 98              Maruti Alto K10 2010-2014 VXI   Hyderabad  2013
# 99    Volkswagen Polo Diesel Comfortline 1.2L     Chennai  2013
#
#     Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0               46000    Diesel    Automatic      First   13.0 kmpl  2143 CC
# ...

# %%
print(df.shape)
print(df2.shape)
# Out:
# (5975, 12)
# (100, 11)

# %%
df.to_csv(f'./{datasetName}_new.csv', index=None)
df2.to_csv(f'./{datasetName}_test.csv', index=None)

# %%
df3 = pd.read_csv(f'./{datasetName}_test.csv')
df3
# Out:
#          ID Marital Status  Gender  Yearly Income  Children  \
# 0   22774.0        Married    Male          60000       1.0
# 1   17517.0         Single    Male          80000       0.0
# 2   11941.0         Single    Male          60000       0.0
# 3   19776.0        Married  Female          40000       0.0
# 4   27295.0         Single    Male          70000       0.0
# ..      ...            ...     ...            ...       ...
# 95  22496.0        Married  Female          30000       1.0
# 96  20235.0         Single    Male          60000       4.0
# 97  16669.0         Single    Male          60000       0.0
# 98  24213.0         Single    Male          10000       0.0
# 99  16326.0         Single    Male          10000       0.0
#
#               Education      Occupation Home Owner  Cars  Commute Distance  \
# 0       Partial College    Professional        Yes     2               5.0
# 1             Bachelors      Management        Yes     1               7.0
# ...

# %%
print(df.shape)
print(df3.shape)
# Out:
# (6909, 13)
# (100, 13)
